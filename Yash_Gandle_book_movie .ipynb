# %% [markdown]
# # Book my movie

# %%
global f
f = 0
 

def t_movie():
    global f
    f = f+1
    print("which movie do you want to watch?")
    print("1,Avenger End Game ")
    print("2,Black Adem ")
    print("3,Wakanda Forever")
    print("4,KGF2")
    movie = int(input("select your movie: "))
    if movie == 4:
      
      center()
      theater()
      return 0
    if f == 1:
      theater()

def theater():
    print("which screen do you want to watch movie: ")
    print("1, PVR ")
    print("2,Inox")
    print("3,Cinepolis")
    a = int(input("choose your screen: "))
    ticket = int(input("number of ticket do you want?: "))
    timing(a)
 

def timing(a):
    time1 = {
        "1": "09.00-12.00",
        "2": "12.10-3.10",
        "3": "4.00-7.00",
        "4": "7.30-10.30"
    }
    time2 = {
        "1": "10.15-1.15",
        "2": "1.25-4.25",
        "3": "4.35-7.35",
        "4": "7.45-10.45"
    }
    time3 = {
        "1": "08.30-11.30",
        "2": "12.40-3.40",
        "3": "03.00-06.00",
        "4": "8.00-10.45"
    }
    if a == 1:
        print("choose your time:")
        print(time1)
        t = input("select your time:")
        x = time1[t]
        print("successful!, enjoy movie at "+x)
    elif a == 2:
        print("choose your time:")
        print(time2)
        t = input("select your time:")
        x = time2[t]
        print("successful!, enjoy movie at "+x)
    elif a == 3:
        print("choose your time:")
        print(time3)
        t = input("select your time:")
        x = time3[t]
        print("successful!, enjoy movie at "+x)
    return 0
 
 
def movie(theater):
    if theater == 1:
        t_movie()
    elif theater == 2:
        t_movie()
    elif theater == 3:
        t_movie()
    elif theater == 4:
        city()
    else:
        print("Please Choose Correct Time")
 
 
def center():
    print("which theater do you want to see movie? ")
    print("1,Inox")
    print("2,Mangala")
    print("3,pvr")
    print("4,Bollywood Squere")
    a = int(input("choose your option: "))
    movie(a)
    return 0
 

def city():
    print("Hi Glad welcome to movie ticket booking: ")
    print("Which City you want to watch movie?:")
    print("1,Pune")
    print("2,Mumbai ")
    print("3,Kolhapur ")
    place = int(input("choose your City: "))
    if place == 1:
      center()
    elif place == 2:
      center()
    elif place == 3:
      center()
    else:
      print("wrong choice")
 
 
city()
# Out:
# Hi Glad welcome to movie ticket booking:
# Which City you want to watch movie?:
# 1,Pune
# 2,Mumbai
# 3,Kolhapur
# choose your City: 1
# which theater do you want to see movie?
# 1,Inox
# 2,Mangala
# 3,pvr
# 4,Bollywood Squere
# choose your option: 3
# which movie do you want to watch?
# 1,Avenger End Game
# 2,Black Adem
# 3,Wakanda Forever
# 4,KGF2
# select your movie: 2
# which screen do you want to watch movie:
# 1, PVR
# 2,Inox
# 3,Cinepolis
# choose your screen: 1
# number of ticket do you want?: 2
# choose your time:
# {'1': '09.00-12.00', '2': '12.10-3.10', '3': '4.00-7.00', '4': '7.30-10.30'}
# select your time:3
# successful!, enjoy movie at 4.00-7.00

# %% [markdown]
# ##
